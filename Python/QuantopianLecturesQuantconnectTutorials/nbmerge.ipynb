# %%
# !ls

# %%
# !pip install nbmerge
# Out:
# ...
#   Created wheel for nbmerge: filename=nbmerge-0.0.4-py2.py3-none-any.whl size=6413 sha256=b009aa9d72574930882d202629b3328e33f6cf65bc6f7822e8999fc6117190ac
#   Stored in directory: /root/.cache/pip/wheels/ce/2d/ef/1833d9299f557279f700d29a3355ad2b5fa9e35c32f84c5b3a
# Successfully built nbmerge
# ...

# %%
# !nbmerge Introduction_to_the_Research_Environment.ipynb Introduction_to_Python.ipynb Introduction_to_Pandas.ipynb Data_Types_and_Data_Structures.ipynb Logical_Operations_and_Loops.ipynb Functions_and_Object_Oriented_Programming.ipynb Introduction_to_NumPy.ipynb Introduction_to_Pandas.ipynb NumPy_and_Basic_Pandas.ipynb Colab_Yahoo_Pandas_Resampling_and_DataFrame.ipynb Colab_Yahoo_Graphical_Representations_of_Data.ipynb > gjhernanndezp_Lab1.ipynb

# %%
# !nbmerge
# Out:
# usage: nbmerge [-h] [-o OUTPUT] [-b [BOUNDARY]] [-i] [-r] [-p PREDICATE_RE]
#                [-v]
#                [files [files ...]]
#
# A tool to merge / concatenate Jupyter (IPython) notebooks
#
# positional arguments:
#   files                 Paths to files to merge
#
# optional arguments:
#   -h, --help            show this help message and exit
#   -o OUTPUT, --output OUTPUT
#                         Write to the specified file
#   -b [BOUNDARY], --boundary [BOUNDARY]
#                         Add boundary metadata to header cells(optionally by
#                         given key)
#   -i, --ignore-underscored
#                         Ignore notebooks with underscore prefix
#   -r, --recursive       Merge all notebooks in subdirectories
#   -p PREDICATE_RE, --predicate-re PREDICATE_RE
#                         Regexp for filename acceptance
#   -v, --verbose         Print progress as processing
