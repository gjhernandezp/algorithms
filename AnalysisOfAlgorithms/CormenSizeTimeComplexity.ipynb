# %% [markdown]
# # 0.(1 microsecond by instruction)
#
# Asuuming that you can execute a million instructions $10^6$ every second, i.e. each instruction takes one microsecond $1\mu s=10^{-6}$ seconds. If you have algorithms take $\bf{ Time\ Complexity}$ steps to solve a porblem of size $n$ as specified in column one. What is the size of the largest porblem that you can solve in the time specified in row one.?
# $$
# \begin{array}{|c|c|c|c|c|c|c|c|}
#  \hline
#  \bf{ Time\ Complexity} & Second  & Minute  & Hour & Day & Year & Century & Mileniun  \\
#   \hline\\
# \lg(n) &   2^{10^{6}}  &  2^{60 \times 10^{6}} &  &  &  &  &  \\
#    \hline\\
# \lg^2(n) &    &   &  &  &  &  &  \\
#    \hline\\
# \sqrt{n} &    &   &  &  &  &  &  \\
#  \hline
#  n &    &   &  &  &  &  &  \\
#  \hline
#  n\lg(n) &    &   &  &  &  &  &  \\
#  \hline
#  n^2 &  1000  & 7745  &  &  &  &  &  \\
#  \hline
#   n^3 &    &   &  &  &  &  &  \\
#  \hline
#   n^4 &    &   &  &  &  &  &  \\
#  \hline
#   2^n &    &   &  &  &  &  &  \\
#  \hline
#  n! &    &   &  &  &  &  &  \\
#  \hline
#  n^n &    &   &  &  &  &  &  \\
#  \hline
# \end{array}
# $$

# %% [markdown]
# $\bf{ Time\ Complexity\ \lg(n) }$
#
# $Second$
# $$ \lg(n) \le 1 * 10^{6}$$
# $$ 2^{\lg(n)} \le 2^{10^{6}}$$
# $$ n \le 2^{10^{6}}$$
#
# $Minute$
# $$ \lg(n) \le 60 \times 10^{6}$$
# $$ 2^{\lg(n)} \le 2^{60 \times 10^{6}}$$
# $$ n \le 2^{60 \times 10^{6}}$$
#
#
# $\bf{ Time\ Complexity\ n^2 }$
#
# $Second$
# $$  n^2 \le 1 * 10^{6}$$
# $$ \sqrt{n^2} \le \sqrt{10^{6}}$$
# $$ n \le 10^3 = 1000 $$
#
# $Minute$
# $$  n^2 \le 60 \times 10^{6}$$
# $$ \sqrt{n^2} \le \sqrt{60 \times10^{6}}$$
# $$ n \le 7745 $$

# %%
import math
# 1. One microsecond by Instructionmath.sqrt(60*10**6)
# Out:
# 7745.966692414834

# %% [markdown]
# # 1.(10  nanoseconds by instruction)
#
# Asuuming that you can execute a 100 million instructions $100 \times 10^6$ every second, i.e. each instrcution takes 10![image.png](data:image/png;base64,...) nanoseconds, 10 $\eta s  =\frac{1}{100 \times 10^6} s $. If you have algorithms take $\bf{ Time\ Complexity}$ steps to solve a poblem of size $n$ as specified in column one. What is the size of the largest porblem that you can solve in the time specified in row one.?
# $$
# \begin{array}{|c|c|c|c|c|c|c|c|}
#  \hline
#  \bf{ Time\ Complexity} & Second  & Minute  & Hour & Day & Year & Century & Mileniun  \\
#   \hline\\
# \lg(n) &    &   &  &  &  &  &  \\
#    \hline\\
# \lg^2(n) &    &   &  &  &  &  &  \\
#    \hline\\
# \sqrt{n} &    &   &  &  &  &  &  \\
#  \hline
#  n &    &   &  &  &  &  &  \\
#  \hline
#  n\lg(n) &    &   &  &  &  &  &  \\
#  \hline
#  n^2 &    &   &  &  &  &  &  \\
#  \hline
#   n^3 &    &   &  &  &  &  &  \\
#  \hline
#   n^4 &    &   &  &  &  &  &  \\
#  \hline
#   2^n &    &   &  &  &  &  &  \\
#  \hline
#  n! &    &   &  &  &  &  &  \\
#  \hline
#  n^n &    &   &  &  &  &  &  \\
#  \hline
# \end{array}
# $$

# %% [markdown]
# # 2.(2.5  nanoseconds by instruction)
#
# Asuuming that you can execute a 400 million instructions $400 \times 10^6$ every second, i.e. each instrcution takes 2.5  nanoseconds, 2.5 $\eta s  =\frac{1}{400 \times 10^6} s $. If you have algorithms take $\bf{ Time\ Complexity}$ steps to solve a poblem of size $n$ as specified in column one. What is the size of the largest porblem that you can solve in the time specified in row one.?
# $$
# \begin{array}{|c|c|c|c|c|c|c|c|}
#  \hline
#  \bf{ Time\ Complexity} & Second  & Minute  & Hour & Day & Year & Century & Mileniun  \\
#   \hline\\
# \lg(n) &    &   &  &  &  &  &  \\
#    \hline\\
# \lg^2(n) &    &   &  &  &  &  &  \\
#    \hline\\
# \sqrt{n} &    &   &  &  &  &  &  \\
#  \hline
#  n &    &   &  &  &  &  &  \\
#  \hline
#  n\lg(n) &    &   &  &  &  &  &  \\
#  \hline
#  n^2 &    &   &  &  &  &  &  \\
#  \hline
#   n^3 &    &   &  &  &  &  &  \\
#  \hline
#   n^4 &    &   &  &  &  &  &  \\
#  \hline
#   2^n &    &   &  &  &  &  &  \\
#  \hline
#  n! &    &   &  &  &  &  &  \\
#  \hline
#  n^n &    &   &  &  &  &  &  \\
#  \hline
# \end{array}
# $$

# %% [markdown]
# # 3. (1 noneosecond by instruction)
#
# Asuuming that you can execute a 1000 million instructions $10^9$ every second, i.e. each instrcution takes 1  nanosecond, 1 $\eta s  =\frac{1}{10^9} s $. If you have algorithms take $\bf{ Time\ Complexity}$ steps to solve a poblem of size $n$ as specified in column one. What is the size of the largest porblem that you can solve in the time specified in row one.?
# $$
# \begin{array}{|c|c|c|c|c|c|c|c|}
#  \hline
#  \bf{ Time\ Complexity} & Second  & Minute  & Hour & Day & Year & Century & Mileniun  \\
#   \hline\\
# \lg(n) &    &   &  &  &  &  &  \\
#    \hline\\
# \lg^2(n) &    &   &  &  &  &  &  \\
#    \hline\\
# \sqrt{n} &    &   &  &  &  &  &  \\
#  \hline
#  n &    &   &  &  &  &  &  \\
#  \hline
#  n\lg(n) &    &   &  &  &  &  &  \\
#  \hline
#  n^2 &    &   &  &  &  &  &  \\
#  \hline
#   n^3 &    &   &  &  &  &  &  \\
#  \hline
#   n^4 &    &   &  &  &  &  &  \\
#  \hline
#   2^n &    &   &  &  &  &  &  \\
#  \hline
#  n! &    &   &  &  &  &  &  \\
#  \hline
#  n^n &    &   &  &  &  &  &  \\
#  \hline
# \end{array}
# $$
