# %% [markdown]
# # ** Test 1 Algorithms UNCode Programming Assignments**

# %% [markdown]
# #**|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||**#

# %% [markdown]
# # **1. Fast Large Fibonacci Number Mod k**
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Your goal in this problem is  $𝑛$-th Fibonacci number *mod* $k$.

# %% [markdown]
# ---
#
# ###**Problem Description**
#
# **Task:** Given one integers $n$ and $k$, find $n$th Fibonacci *mod* $k$, that is, $F_n$ *mod* $k$.
#
# **Input Format:** The input consists of a single integer $n$.
#
# **Constraints:** $0 \leq n \leq 10^{24}$.
#
# **Output Format:** Output $F_n \mod k$.

# %% [markdown]
# **Sample testcase**
#
# ```python
# #run this sample testcase on a cell to help you validate your solution
# fibonacci_mod(331,10)
#
# #𝐹_331 = 668 996 615 388 005 031 531 000 081 241 745 415 306 766 517 246 774 551 964 595 292 186 469.
# #  --> Expected output: 9
#
# fibonacci_mod(1000,5)
#
# #  --> Expected output: 0
#
# fibonacci_mod(355674562,13)
#
# #  --> Expected output: 12
#
#
# ```
#
# ---

# %% [markdown]
# **Solution**

# %%
#Do not change this function's name, parameters or output format. It will be used in automatic grading.

def fibonacci_mod(n,k):

  f_n_mod_k = 0
  
  #Your code goes here



  return f_n_mod_kt

# %% [markdown]
# #**|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||**#

# %% [markdown]
# # **2.  Distribution of the Number of Fucntion Calls and Worst Cases List for Greatest Common Divisor**
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# "The Euclidean algorithm is described in Euclid's Elements, Book VII, Propositions 1 and 2.
#
# How many divisions do you need to find the greatest common divisor of two numbers? Gabriel Lamé answered that in 1844. His was the First Application of Fibonacci Numbers and the first result in Computational complexity theory" https://www.quora.com/How-could-be-the-time-complexity-of-euclids-gcd-algorithm-be-O-n3
#
# On this task you're asked to return the distribution the number of function calls including the initial call in the count (= number of reursive calls +1 = number of divisons +1)  and the list of worst cases for the following Greatest Common Divisor function $gcd(a,b)$ when applied to $0 \le b \le a \le n$.
#
# ```python
# # Python program to demonstrate Basic Euclidean Algorithm modfied swaping a and b like in DVP
# # from https://www.geeksforgeeks.org/euclidean-algorithms-basic-and-extended/
#
#
# # Function to return gcd of a and b
# def gcd(a, b):
#     if b == 0 :
#         return a
#     return gcd(b,a%b)
# ```

# %% [markdown]
# ---
#
# ###**Problem Description**
#
#
# **Task:** Return the distribution the number of function calls for $gcd(a,b)$ with $0 \le b \le a \le n$ (include the initial call in the count) and the list of worst cases, i.e., the pairs where for it takes more function calls.
#
# **Input Format:**  One integer $n$ is given.
#
# **Constraints:**   $0 \le n \le 1000$.
#
# **Output Format:** An dictionary with the distribution and a list of worst cases.
#
#
# ---

# %% [markdown]
# **Sample testcase**
#
# ```python
# #run this sample testcase on a cell to help you validate your solution
#
# dist_gcd(4)
#
# #  --> Expected output: ({1: 5, 2: 8, 3: 2}, [[4, 3], [3, 2]])
#
# dist_gcd(8)
#
# #  --> Expected output: ({1: 9, 2: 20, 3: 11, 4: 4, 5: 1}, [[8, 5]])
#
# dist_gcd(10)
#
# #  --> Expected output:({1: 11, 2: 27, 3: 19, 4: 8, 5: 1}, [[8, 5]])
#
# dist_gcd(30)
#
# #  --> Expected output: ({1: 31, 2: 111, 3: 137, 4: 122, 5: 69, 6: 22, 7: 4},
#  [[30, 19], [29, 21], [29, 18], [21, 13]])
#
# ```
# ---

# %% [markdown]
# **Solution**

# %%
#Do not change this function's name, parameters or output format. It will be used in automatic grading.

def dist_gcd(n):
  times = {}
  worst = []

  #Your code goes here

  times = sorted(times.items(), key = lambda kv: kv[0])
  times = dict(times)
  
  return times,worst
