# %% [markdown]
# # **Algorithms Second Test**

# %% [markdown]
# #**|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||**#

# %% [markdown]
# ## **1. Incremental Convex Hulls**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# On this task you're asked to list the partial convex hulls produced by the incremental convex hull algorithm when applied to of a set of points in the plane $(x_1,y_1),(x_2,y_2),\dots,(x_n,y_n)$; when the points are included sorted by the first corrdinate $x$.

# %% [markdown]
# ---
#
# ###**Problem Description**
#
#
# **Task:** Generate the partial convex hulls produced by the incremental convex hull algorithm when applied to of a set of points in the plane sorted by the first corrdinate $x$.
#
# **Input Format:** A list $[[x_1,y_1],\cdots,[x_n,y_n)]]$ of $n$ points.
#
# **Constraints:** $1 \leq n \leq 10^4$.
#
# **Output Format:** A lists of of lists of points.
#
#
# ---

# %% [markdown]
# **Sample testcase**
#
# ```python
# #run this sample testcase on a cell to help you validate your solution
# incremental_convex_hull([[0, 0], [3, -1], [4, 5], [-1, 4], [6, 6]])
#
# #  --> Expected output:[ [[0, 0]], [[0, 0], [3, -1]], [[0, 0], [3, -1], [4, 5]], [[0, 0], [3, -1], [4, 5], [-1, 4]], [[-1, 4], [0, 0], [3, -1], [6, 6]] ]
# ```
#
# ---

# %% [markdown]
# **Solution**

# %%
#Do not change this function's name, parameters or output format. It will be used in automatic grading.

def incremental_convex_hull(points):
  
  convex_hulls = []
 
  #Your code goes here

  number_of_solutions = 0

  return convex_hulls

# %% [markdown]
# #**|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||**#

# %% [markdown]
# ## **2. N-Queens solutions**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# On this task you're asked to solve the n-Queens problem but on this variation you won't be asked if a solution exists, you'll be asked to count how many solutions can be found for a given board of N x N squares.

# %% [markdown]
# ---
#
# ###**Problem Description**
#
#
# **Task:** Count all possible solutions for N-Queens problem  for a NxN board.
#
# **Input Format:** An integer $N$ denoting dimensions of the board.
#
# **Constraints:** $1 \leq N \leq 10$.
#
# **Output Format:** Output the number of possible solutions.
#
#
# ---

# %% [markdown]
# **Sample testcase**
#
# ```python
# #run this sample testcase on a cell to help you validate your solution
# count_n_queens_solutions(7)
#
# #  --> Expected output: 40
# ```
#
# ---

# %% [markdown]
# **Solution**

# %%
#Do not change this function's name, parameters or output format. It will be used in automatic grading.

def count_n_queens_solutions(N):
  
  #Your code goes here

  number_of_solutions = 0

  return number_of_solutions

# %% [markdown]
# #**|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||**#

# %% [markdown]
# # **3. Maximum Value of the Loot**

# %% [markdown]
# ![image-001.png](data:image/png;base64,...)

# %% [markdown]
# ## **Problem Description**

# %% [markdown]
# ---
#
# **Task:** The goal of this code problem is to implement an algorithm for the fractional knapsack problem.
#
# **Input Format:** Input contains the capacity of a knapsack as an integer valued number and weights and values lists for each of the $i$ items.
#
# **Constraints:** $1 \leq n \leq 10^3$, $1 \leq W \leq 2 \cdot 10^6$, $1 \leq v_i \leq 2 \cdot 10^6$, $1 \leq w_i \leq 2 \cdot 10^6$ for all $1 \leq i \leq n$. All the numbers are integers.
#
# **Output Format:** Output the maximal value of fractions of items that fit into the knapsack.
#
# ---

# %% [markdown]
# **Sample testcase**
#
# > ```python
# > def get_optimal_value(capacity = 50, weights = [20,50,30], values = [60,100,120])
# >#Expected Output --> 180
# > #To achieve the value 180, we take the first item and the third item into the bag.
# ```

# %% [markdown]
# **Solution**

# %%
#Do not change this function's name, parameters or output format. It will be used in automatic grading.

def get_optimal_value(capacity, weights, values):
    value = 0

    #Your code goes here

    return value
