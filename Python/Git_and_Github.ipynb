# %% [markdown]
# ### Fast class of Git and Github
#
# *By: Angel Mateo Gonzalez Bejarano*
#
# This notebook resumes the more relevant aspects of Git and Github
#
# If you want to know more, pls visit [this link](https://www.youtube.com/watch?v=HiXLkL42tMU)

# %% [markdown]
# #### **Resume of the video**
#
# The video shows a brief intro to the VCS (Version Control System) and the intuitive idea of what is inside
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Then, the video goes to explain how Git works, and the most important concepts when you are working with it.
#
# There are some "stages" that you must to complete for achieve a gratefuly and succesfully working flow
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Later, the video shows the basic Git commands, the commands that are very used for all when they are making software in general.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# The video will show you how to download git, create a folder, an archive, and then how to follow all the changes in your workflow using the basic git commands, remember that we're talking about Git, so the changes and your following on that, only will disponible be at your local machine!
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Finally, the video shows you how to integrate Git with Github, that is a powerful tool to achieve the review of your workflow, and this becomes more powerful and useful when you are working with your team.
#
# Many companies around the world are using Git and Github/GitLab for follow all the programing workflow and their teams.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Note:** Due to #BlackLivesMatter movement, and the solidarity of many companies (including software companies) the name of the branch `master` that appears on the video is actually deprecated, in its place, the principal branch now is called `main`
